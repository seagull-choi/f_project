# %%
# !git clone https://github.com/seagull-choi/f_project.git
# Out:
# Cloning into 'f_project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# 연동할 Github 계정 정보 설정
# !git config --global user.email "seagull.choi@gmail.com"
# !git config --global user.name "seagull-choi"

# %%
#등록 여부 확인
# !git config --global --list
# Out:
# user.name=seagull-choi
# user.email=seagull.choi@gmail.com

# %%
# %cd f_project
# Out:
# /content/f_project

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/f_project/.git/

# %%
from getpass import getpass

# 토큰 입력
token = getpass('Enter your GitHub Personal Access Token: ')
# Out:
# Enter your GitHub Personal Access Token: ··········

# %%
# push 시에 token 값을 포함하여 수행하기 위한 설정 추가
# !git remote set-url origin https://seagull-choi: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@github.com/seagull-choi/f_project.git
# !git push origin main
# Out:
# Everything up-to-date

# %%
#  google drive 연동 상태 확인
# !ls "/content/drive/My Drive/Colab\ Notebooks"
# Out:
# ls: cannot access '/content/drive/My Drive/Colab\ Notebooks': No such file or directory

# %%
# google drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-15-25d39d135b9f> in <cell line: 0>()
#       1 # google drive 마운트
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
# ...

# %%
# 예: Colab Notebooks 폴더에 있는 final_project.ipynb 복사
# !cp /content/drive/MyDrive/Colab\ Notebooks/final_project.ipynb /content/f_project/

# %%
# !git checkout -b colab-update
# !git add final_project.ipynb
# !git commit -m "Add file from Colab"

# %%
# !git push origin colab-update
